# %%
from collections import defaultdict
import pandas as pd
from flights import flightaware
import json

# %%
flights = flightaware.Flights()

# %%
params ={
    'minLon':-180,
    'minLat':-90,
    'maxLon':-76.3414192199707,
    'maxLat':90,
}

# %%
flights.get(params=params)
# Out:
# [{'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-76.46853, 41.58266]},
#     'properties': {'flight_id': 'AAY852-1604055600-schedule-0098:0',
#      'prefix': 'AAY',
#      'direction': 61,
#      'type': 'A319',
#      'ident': 'AAY852',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236380'},
#      'origin': {'icao': 'KPIE', 'iata': 'PIE', 'isUSAirport': True},
#      'destination': {'icao': 'KSWF',
#       'iata': 'SWF',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 19090,
#      'projected': 0,
#      'altitude': 230,
#      'altitudeChange': '-',
#      'groundspeed': 498}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.20825, 40.20154]},
#     'properties': {'flight_id': 'SWA1932-1604059042-airline-0170:0',
#      'prefix': 'SWA',
#      'direction': 298,
#      'type': 'B737',
#      'ident': 'SWA1932',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604237940'},
#      'origin': {'icao': 'KDCA', 'iata': 'DCA', 'isUSAirport': True},
#      'destination': {'icao': 'KMDW',
#       'iata': 'MDW',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 18880,
#      'projected': 0,
#      'altitude': 320,
#      'altitudeChange': '-',
#      'groundspeed': 394}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-100.9301, 25.55141]},
#     'properties': {'flight_id': 'VOI510-1604053260-schedule-0000:0',
#      'prefix': 'VOI',
#      'direction': 108,
#      'type': 'A20N',
#      'ident': 'VOI510',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236080'},
#      'origin': {'icao': 'MMTJ', 'iata': 'TIJ', 'isUSAirport': False},
#      'destination': {'icao': 'MMMY',
#       'iata': 'MTY',
#       'TZ': ':America/Monterrey',
#       'isUSAirport': False},
#      'prominence': 20060,
#      'projected': 0,
#      'altitude': 236,
#      'altitudeChange': 'D',
#      'groundspeed': 412}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.10352, 27.76087]},
#     'properties': {'flight_id': 'N108F-1604232609-adhoc-0',
#      'prefix': 'N10',
#      'direction': 208,
#      'type': 'B350',
#      'ident': 'N108F',
#      'icon': 'twin_small',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '30.09N/81.68W', 'iata': None, 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 163,
#      'projected': 0,
#      'altitude': 163,
#      'altitudeChange': '-',
#      'groundspeed': 284}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-119.49117, 35.12759]},
#     'properties': {'flight_id': 'N810BE-1604232687-7-2-10:0',
#      'prefix': 'N81',
#      'direction': 306,
#      'type': 'C560',
#      'ident': 'N810BE',
#      'icon': 'jet_nonswept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604237197'},
#      'origin': {'icao': 'KVNY', 'iata': 'VNY', 'isUSAirport': True},
#      'destination': {'icao': 'KSJC',
#       'iata': 'SJC',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 8060,
#      'projected': 0,
#      'altitude': 260,
#      'altitudeChange': '-',
#      'groundspeed': 397}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-88.48301, 36.9505]},
#     'properties': {'flight_id': 'SKW4802-1604059364-airline-0215:0',
#      'prefix': 'SKW',
#      'direction': 218,
#      'type': 'E170',
#      'ident': 'SKW4802',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604240400'},
#      'origin': {'icao': 'KCVG', 'iata': 'CVG', 'isUSAirport': True},
#      'destination': {'icao': 'KIAH',
#       'iata': 'IAH',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 26860,
#      'projected': 0,
#      'altitude': 340,
#      'altitudeChange': '-',
#      'groundspeed': 379}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.46759, 40.7737]},
#     'properties': {'flight_id': 'RPA5676-1604061120-schedule-0155:2',
#      'prefix': 'RPA',
#      'direction': 60,
#      'type': 'E170',
#      'ident': 'RPA5676',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604238900'},
#      'origin': {'icao': 'KIND', 'iata': 'IND', 'isUSAirport': True},
#      'destination': {'icao': 'KLGA',
#       'iata': 'LGA',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 18130,
#      'projected': 0,
#      'altitude': 370,
#      'altitudeChange': 'C',
#      'groundspeed': 521}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-88.4678, 33.87808]},
#     'properties': {'flight_id': 'AAY863-1604058300-schedule-0024:0',
#      'prefix': 'AAY',
#      'direction': 313,
#      'type': 'A320',
#      'ident': 'AAY863',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604238420'},
#      'origin': {'icao': 'KPIE', 'iata': 'PIE', 'isUSAirport': True},
#      'destination': {'icao': 'KSGF',
#       'iata': 'SGF',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 29640,
#      'projected': 0,
#      'altitude': 380,
#      'altitudeChange': '-',
#      'groundspeed': 370}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-80.26855, 39.29968]},
#     'properties': {'flight_id': 'AAY1432-1604061120-schedule-0180:0',
#      'prefix': 'AAY',
#      'direction': 179,
#      'type': 'A319',
#      'ident': 'AAY1432',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604241600'},
#      'origin': {'icao': 'KPIT', 'iata': 'PIT', 'isUSAirport': True},
#      'destination': {'icao': 'KPGD',
#       'iata': 'PGD',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 22849,
#      'projected': 0,
#      'altitude': 313,
#      'altitudeChange': 'C',
#      'groundspeed': 400}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-76.40489, 3.40888]},
#     'properties': {'flight_id': 'ARE4055-1604053920-schedule-0009:0',
#      'prefix': 'ARE',
#      'direction': 10,
#      'type': 'A320',
#      'ident': 'ARE4055',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604235120'},
#      'origin': {'icao': 'SKBO', 'iata': 'BOG', 'isUSAirport': False},
#      'destination': {'icao': 'SKCL',
#       'iata': 'CLO',
#       'TZ': ':America/Bogota',
#       'isUSAirport': False},
#      'prominence': 1007,
#      'projected': 0,
#      'altitude': 53,
#      'altitudeChange': 'D',
#      'groundspeed': 152}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-77.12723, 44.25101]},
#     'properties': {'flight_id': 'SPR750-1604178557-dlad-7424214:2',
#      'prefix': 'SPR',
#      'direction': 71,
#      'type': 'BE30',
#      'ident': 'SPR750',
#      'icon': 'twin_small',
#      'ga': True,
#      'landingTimes': {'estimated': '1604241220'},
#      'origin': {'icao': 'CYYZ', 'iata': 'YYZ', 'isUSAirport': False},
#      'destination': {'icao': 'CYHZ',
#       'iata': 'YHZ',
#       'TZ': ':America/Halifax',
#       'isUSAirport': False},
#      'prominence': 22040,
#      'projected': 0,
#      'altitude': 290,
#      'altitudeChange': '-',
#      'groundspeed': 387}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-89.43777, 13.59097]},
#     'properties': {'flight_id': 'TAI561-1604043817-airline-0055:0',
#      'prefix': 'TAI',
#      'direction': 138,
#      'type': 'A320',
#      'ident': 'TAI561',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604235600'},
#      'origin': {'icao': 'KSFO', 'iata': 'SFO', 'isUSAirport': True},
#      'destination': {'icao': 'MSLP',
#       'iata': 'SAL',
#       'TZ': ':America/El_Salvador',
#       'isUSAirport': False},
#      'prominence': 14586,
#      'projected': 0,
#      'altitude': 78,
#      'altitudeChange': 'D',
#      'groundspeed': 280}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.63897, 32.16615]},
#     'properties': {'flight_id': 'JBU181-1604058300-schedule-0037:0',
#      'prefix': 'JBU',
#      'direction': 337,
#      'type': 'A320',
#      'ident': 'JBU181',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604237940'},
#      'origin': {'icao': 'KFLL', 'iata': 'FLL', 'isUSAirport': True},
#      'destination': {'icao': 'KBNA',
#       'iata': 'BNA',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 24765,
#      'projected': 0,
#      'altitude': 381,
#      'altitudeChange': '-',
#      'groundspeed': 419}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-79.24116, 25.95595]},
#     'properties': {'flight_id': 'JBU1557-1604156465-1-1-151:0',
#      'prefix': 'JBU',
#      'direction': 100,
#      'type': 'A320',
#      'ident': 'JBU1557',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604246700'},
#      'origin': {'icao': 'KFLL', 'iata': 'FLL', 'isUSAirport': True},
#      'destination': {'icao': 'SKBO',
#       'iata': 'BOG',
#       'TZ': ':America/Bogota',
#       'isUSAirport': False},
#      'prominence': 23474,
#      'projected': 0,
#      'altitude': 194,
#      'altitudeChange': 'C',
#      'groundspeed': 405}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-101.48086, 21.00188]},
#     'properties': {'flight_id': 'UAL820-1604051765-fa-0004:0',
#      'prefix': 'UAL',
#      'direction': 319,
#      'type': 'B738',
#      'ident': 'UAL820',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604248920'},
#      'origin': {'icao': 'MMMX', 'iata': 'MEX', 'isUSAirport': False},
#      'destination': {'icao': 'KSFO',
#       'iata': 'SFO',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 55440,
#      'projected': 0,
#      'altitude': 360,
#      'altitudeChange': '-',
#      'groundspeed': 459}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.09321, 29.06596]},
#     'properties': {'flight_id': 'FFT1167-1604055600-schedule-0043:0',
#      'prefix': 'FFT',
#      'direction': 176,
#      'type': 'A20N',
#      'ident': 'FFT1167',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604235900'},
#      'origin': {'icao': 'KPHL', 'iata': 'PHL', 'isUSAirport': True},
#      'destination': {'icao': 'KMCO',
#       'iata': 'MCO',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 8610,
#      'projected': 0,
#      'altitude': 123,
#      'altitudeChange': 'D',
#      'groundspeed': 318}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-87.17514, 42.09924]},
#     'properties': {'flight_id': 'AIC127-1604004900-schedule-0356:2',
#      'prefix': 'AIC',
#      'direction': 179,
#      'type': 'B77W',
#      'ident': 'AIC127',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604235223'},
#      'origin': {'icao': 'VIDP', 'iata': 'DEL', 'isUSAirport': False},
#      'destination': {'icao': 'KORD',
#       'iata': 'ORD',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 34272,
#      'projected': 0,
#      'altitude': 63,
#      'altitudeChange': 'D',
#      'groundspeed': 292}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-86.52733, 36.77552]},
#     'properties': {'flight_id': 'SWA2056-1604060611-airline-0014:0',
#      'prefix': 'SWA',
#      'direction': 191,
#      'type': 'B737',
#      'ident': 'SWA2056',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604237340'},
#      'origin': {'icao': 'KIND', 'iata': 'IND', 'isUSAirport': True},
#      'destination': {'icao': 'KATL',
#       'iata': 'ATL',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 12870,
#      'projected': 0,
#      'altitude': 330,
#      'altitudeChange': '-',
#      'groundspeed': 404}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.76807, 41.95232]},
#     'properties': {'flight_id': 'N2040U-1604229015-1-5-93:0',
#      'prefix': 'N20',
#      'direction': 198,
#      'type': 'BE36',
#      'ident': 'N2040U',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '1604239380'},
#      'origin': {'icao': 'KVLL', 'iata': 'VLL', 'isUSAirport': True},
#      'destination': {'icao': '5I4',
#       'iata': '5I4',
#       'TZ': ':America/Indiana/Indianapolis',
#       'isUSAirport': True},
#      'prominence': 3534,
#      'projected': 0,
#      'altitude': 62,
#      'altitudeChange': '-',
#      'groundspeed': 95}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-93.52713, 45.38969]},
#     'properties': {'flight_id': 'N35NM-1604234333-adhoc-0:0',
#      'prefix': 'N35',
#      'direction': 340,
#      'type': 'A109',
#      'ident': 'N35NM',
#      'icon': 'helicopter',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '45.02N/93.32W', 'iata': None, 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 23,
#      'projected': 0,
#      'altitude': 23,
#      'altitudeChange': '-',
#      'groundspeed': 119}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.04651, 29.0789]},
#     'properties': {'flight_id': 'N214RK-1604233860-adhoc-0:0',
#      'prefix': 'N21',
#      'direction': 0,
#      'type': '',
#      'ident': 'N214RK',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '29.05N/81.07W', 'iata': None, 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': -2,
#      'projected': 0,
#      'altitude': -2,
#      'altitudeChange': 'D',
#      'groundspeed': 5}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-104.23781, 23.94978]},
#     'properties': {'flight_id': 'ESF302-1604233245-adhoc-0:0',
#      'prefix': 'ESF',
#      'direction': 306,
#      'type': '',
#      'ident': 'ESF302',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'MMSP', 'iata': 'SLP', 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 320,
#      'projected': 0,
#      'altitude': 320,
#      'altitudeChange': '-',
#      'groundspeed': 459}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-118.83331, 39.47951]},
#     'properties': {'flight_id': 'N904CF-1604233687-adhoc-0:0',
#      'prefix': 'N90',
#      'direction': 95,
#      'type': '',
#      'ident': 'N904CF',
#      'icon': 'helicopter',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '39.53N/119.81W', 'iata': None, 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 48,
#      'projected': 0,
#      'altitude': 48,
#      'altitudeChange': 'D',
#      'groundspeed': 134}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-93.54999, 43.31126]},
#     'properties': {'flight_id': 'EDV4639-1604059200-schedule-0082:0',
#      'prefix': 'EDV',
#      'direction': 6,
#      'type': 'CRJ9',
#      'ident': 'EDV4639',
#      'icon': 'jet_swept',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236260'},
#      'origin': {'icao': 'KMCI', 'iata': 'MCI', 'isUSAirport': True},
#      'destination': {'icao': 'KMSP',
#       'iata': 'MSP',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 11692,
#      'projected': 0,
#      'altitude': 316,
#      'altitudeChange': 'D',
#      'groundspeed': 356}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-78.55595, 44.14975]},
#     'properties': {'flight_id': 'JZA8827-1604059364-airline-0043:0',
#      'prefix': 'JZA',
#      'direction': 239,
#      'type': 'CRJ9',
#      'ident': 'JZA8827',
#      'icon': 'jet_swept',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236500'},
#      'origin': {'icao': 'CYUL', 'iata': 'YUL', 'isUSAirport': False},
#      'destination': {'icao': 'CYYZ',
#       'iata': 'YYZ',
#       'TZ': ':America/Toronto',
#       'isUSAirport': False},
#      'prominence': 7761,
#      'projected': 0,
#      'altitude': 199,
#      'altitudeChange': 'D',
#      'groundspeed': 304}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-99.70987, 30.78529]},
#     'properties': {'flight_id': 'NKS327-1604059200-schedule-0103:0',
#      'prefix': 'NKS',
#      'direction': 282,
#      'type': 'A20N',
#      'ident': 'NKS327',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604243940'},
#      'origin': {'icao': 'KIAH', 'iata': 'IAH', 'isUSAirport': True},
#      'destination': {'icao': 'KLAX',
#       'iata': 'LAX',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 39600,
#      'projected': 0,
#      'altitude': 360,
#      'altitudeChange': '-',
#      'groundspeed': 407}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-98.1136, 19.68681]},
#     'properties': {'flight_id': 'SLI820-1604210580-airline-0114:0',
#      'prefix': 'SLI',
#      'direction': 80,
#      'type': 'E190',
#      'ident': 'SLI820',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604239785'},
#      'origin': {'icao': 'MMMX', 'iata': 'MEX', 'isUSAirport': False},
#      'destination': {'icao': 'MMMD',
#       'iata': 'MID',
#       'TZ': ':America/Merida',
#       'isUSAirport': False},
#      'prominence': 13988,
#      'projected': 0,
#      'altitude': 269,
#      'altitudeChange': 'C',
#      'groundspeed': 394}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-82.85676, 32.9608]},
#     'properties': {'flight_id': 'AAY887-1604060220-schedule-0040:0',
#      'prefix': 'AAY',
#      'direction': 348,
#      'type': 'A320',
#      'ident': 'AAY887',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236920'},
#      'origin': {'icao': 'KPIE', 'iata': 'PIE', 'isUSAirport': True},
#      'destination': {'icao': 'KTYS',
#       'iata': 'TYS',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 16650,
#      'projected': 0,
#      'altitude': 370,
#      'altitudeChange': 'D',
#      'groundspeed': 425}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-87.4688, 41.88193]},
#     'properties': {'flight_id': 'GTI8438-1604204837-3-5-188:0',
#      'prefix': 'GTI',
#      'direction': 17,
#      'type': 'B744',
#      'ident': 'GTI8438',
#      'icon': 'heavy_4e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604235106'},
#      'origin': {'icao': 'PANC', 'iata': 'ANC', 'isUSAirport': True},
#      'destination': {'icao': 'KORD',
#       'iata': 'ORD',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 8250,
#      'projected': 0,
#      'altitude': 50,
#      'altitudeChange': '-',
#      'groundspeed': 197}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.86008, 39.95714]},
#     'properties': {'flight_id': 'RPA4345-1604061120-schedule-0117:2',
#      'prefix': 'RPA',
#      'direction': 88,
#      'type': 'E170',
#      'ident': 'RPA4345',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604238300'},
#      'origin': {'icao': 'KIND', 'iata': 'IND', 'isUSAirport': True},
#      'destination': {'icao': 'KPHL',
#       'iata': 'PHL',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 12013,
#      'projected': 0,
#      'altitude': 293,
#      'altitudeChange': 'C',
#      'groundspeed': 513}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-161.74371, 42.06216]},
#     'properties': {'flight_id': 'UAL838-1604045280-schedule-0689:0',
#      'prefix': 'UAL',
#      'direction': 92,
#      'type': 'B789',
#      'ident': 'UAL838',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604249760'},
#      'origin': {'icao': 'RJAA', 'iata': 'NRT', 'isUSAirport': False},
#      'destination': {'icao': 'KSFO',
#       'iata': 'SFO',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 127200,
#      'projected': 1}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-91.32099, 32.04758]},
#     'properties': {'flight_id': 'N567RD-1604160490-12-0-182:0',
#      'prefix': 'N56',
#      'direction': 235,
#      'type': 'M20P',
#      'ident': 'N567RD',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '1604239776'},
#      'origin': {'icao': 'KOSX', 'iata': 'OSX', 'isUSAirport': True},
#      'destination': {'icao': 'KHPY',
#       'iata': 'HPY',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 5467,
#      'projected': 0,
#      'altitude': 77,
#      'altitudeChange': '-',
#      'groundspeed': 176}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-80.46392, 26.14188]},
#     'properties': {'flight_id': 'N9764F-1604234385-adhoc-0:0',
#      'prefix': 'N97',
#      'direction': 317,
#      'type': 'C172',
#      'ident': 'N9764F',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KHWO', 'iata': 'HWO', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 18,
#      'projected': 0,
#      'altitude': 18,
#      'altitudeChange': '-',
#      'groundspeed': 112}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-80.13059, 26.24775]},
#     'properties': {'flight_id': 'N944TT-1604234185-adhoc-0',
#      'prefix': 'N94',
#      'direction': 103,
#      'type': 'C172',
#      'ident': 'N944TT',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KPMP', 'iata': 'PMP', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 2,
#      'projected': 0,
#      'altitude': 2,
#      'altitudeChange': 'D',
#      'groundspeed': 55}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.34083, 28.95689]},
#     'properties': {'flight_id': 'N650BD-1604203132-3-7-53:0',
#      'prefix': 'N65',
#      'direction': 151,
#      'type': 'C414',
#      'ident': 'N650BD',
#      'icon': 'twin_small',
#      'ga': True,
#      'landingTimes': {'estimated': '1604239500'},
#      'origin': {'icao': '0J6', 'iata': '0J6', 'isUSAirport': True},
#      'destination': {'icao': 'KFXE',
#       'iata': 'FXE',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 12580,
#      'projected': 0,
#      'altitude': 148,
#      'altitudeChange': '-',
#      'groundspeed': 188}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-107.45433, 24.2449]},
#     'properties': {'flight_id': 'VOI548-1604056563-airline-0045:0',
#      'prefix': 'VOI',
#      'direction': 135,
#      'type': 'A320',
#      'ident': 'VOI548',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604239560'},
#      'origin': {'icao': 'MMTJ', 'iata': 'TIJ', 'isUSAirport': False},
#      'destination': {'icao': 'MMZH',
#       'iata': 'ZIH',
#       'TZ': ':America/Mexico_City',
#       'isUSAirport': False},
#      'prominence': 38480,
#      'projected': 0,
#      'altitude': 370,
#      'altitudeChange': '-',
#      'groundspeed': 458}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.6516, 30.62206]},
#     'properties': {'flight_id': 'SWA2073-1604062168-airline-0289:0',
#      'prefix': 'SWA',
#      'direction': 322,
#      'type': 'B738',
#      'ident': 'SWA2073',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604238567'},
#      'origin': {'icao': 'KJAX', 'iata': 'JAX', 'isUSAirport': True},
#      'destination': {'icao': 'KBNA',
#       'iata': 'BNA',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 2736,
#      'projected': 0,
#      'altitude': 76,
#      'altitudeChange': 'C',
#      'groundspeed': 270}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.75799, 28.49514]},
#     'properties': {'flight_id': 'N945MC-1604233947-adhoc-0:0',
#      'prefix': 'N94',
#      'direction': 264,
#      'type': 'C172',
#      'ident': 'N945MC',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KORL', 'iata': 'ORL', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 21,
#      'projected': 0,
#      'altitude': 21,
#      'altitudeChange': 'D',
#      'groundspeed': 73}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.3935, 30.48289]},
#     'properties': {'flight_id': 'FFT1190-1604061120-schedule-0195:0',
#      'prefix': 'FFT',
#      'direction': 359,
#      'type': 'A321',
#      'ident': 'FFT1190',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604238360'},
#      'origin': {'icao': 'KMCO', 'iata': 'MCO', 'isUSAirport': True},
#      'destination': {'icao': 'KRDU',
#       'iata': 'RDU',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 17190,
#      'projected': 0,
#      'altitude': 382,
#      'altitudeChange': 'C',
#      'groundspeed': 440}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.45094, 38.28635]},
#     'properties': {'flight_id': 'AAL1839-1604059364-airline-0172:0',
#      'prefix': 'AAL',
#      'direction': 253,
#      'type': 'B738',
#      'ident': 'AAL1839',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604244420'},
#      'origin': {'icao': 'KDCA', 'iata': 'DCA', 'isUSAirport': True},
#      'destination': {'icao': 'KDFW',
#       'iata': 'DFW',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 41760,
#      'projected': 0,
#      'altitude': 360,
#      'altitudeChange': '-',
#      'groundspeed': 350}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.87402, 27.8574]},
#     'properties': {'flight_id': 'N8258W-1604233274-adhoc-0',
#      'prefix': 'N82',
#      'direction': 81,
#      'type': 'P28A',
#      'ident': 'N8258W',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KSPG', 'iata': 'SPG', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 19,
#      'projected': 0,
#      'altitude': 19,
#      'altitudeChange': 'D',
#      'groundspeed': 97}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-80.53903, 26.0862]},
#     'properties': {'flight_id': 'GAJ514-1604229101-7-0-83:0',
#      'prefix': 'GAJ',
#      'direction': 304,
#      'type': 'C56X',
#      'ident': 'GAJ514',
#      'icon': 'jet_nonswept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604244600'},
#      'origin': {'icao': 'KMIA', 'iata': 'MIA', 'isUSAirport': True},
#      'destination': {'icao': 'KAUS',
#       'iata': 'AUS',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 14454,
#      'projected': 0,
#      'altitude': 146,
#      'altitudeChange': 'C',
#      'groundspeed': 328}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-77.09764, 35.55322]},
#     'properties': {'flight_id': 'N15268-1604232593-adhoc-0:0',
#      'prefix': 'N15',
#      'direction': 105,
#      'type': 'PA32',
#      'ident': 'N15268',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KJNX', 'iata': 'JNX', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 11,
#      'projected': 0,
#      'altitude': 11,
#      'altitudeChange': 'D',
#      'groundspeed': 95}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-80.2978, 28.17586]},
#     'properties': {'flight_id': 'AAY1467-1604055600-schedule-0107:0',
#      'prefix': 'AAY',
#      'direction': 159,
#      'type': 'A319',
#      'ident': 'AAY1467',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236260'},
#      'origin': {'icao': 'KPIT', 'iata': 'PIT', 'isUSAirport': True},
#      'destination': {'icao': 'KPBI',
#       'iata': 'PBI',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 18000,
#      'projected': 0,
#      'altitude': 240,
#      'altitudeChange': 'D',
#      'groundspeed': 411}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-79.82694, 34.49806]},
#     'properties': {'flight_id': 'N309JL-1604227213-5-0-34:0',
#      'prefix': 'N30',
#      'direction': 223,
#      'type': 'COL4',
#      'ident': 'N309JL',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '1604235097'},
#      'origin': {'icao': 'KSUT', 'iata': 'SUT', 'isUSAirport': True},
#      'destination': {'icao': 'KUDG',
#       'iata': 'UDG',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 315,
#      'projected': 0,
#      'altitude': 15,
#      'altitudeChange': 'D',
#      'groundspeed': 86}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-90.82837, 33.15958]},
#     'properties': {'flight_id': 'N607DB-1604181543-9-3-241:0',
#      'prefix': 'N60',
#      'direction': 63,
#      'type': 'C525',
#      'ident': 'N607DB',
#      'icon': 'jet_nonswept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604237640'},
#      'origin': {'icao': 'KCLL', 'iata': 'CLL', 'isUSAirport': True},
#      'destination': {'icao': 'KMDQ',
#       'iata': 'MDQ',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 19950,
#      'projected': 0,
#      'altitude': 350,
#      'altitudeChange': '-',
#      'groundspeed': 449}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-90.21196, 28.92215]},
#     'properties': {'flight_id': 'NKS2821-1604059200-schedule-0042:0',
#      'prefix': 'NKS',
#      'direction': 104,
#      'type': 'A320',
#      'ident': 'NKS2821',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604239740'},
#      'origin': {'icao': 'KIAH', 'iata': 'IAH', 'isUSAirport': True},
#      'destination': {'icao': 'KFLL',
#       'iata': 'FLL',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 23450,
#      'projected': 0,
#      'altitude': 350,
#      'altitudeChange': '-',
#      'groundspeed': 522}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-77.02252, 40.41642]},
#     'properties': {'flight_id': 'JIA5143-1604060220-schedule-0106:0',
#      'prefix': 'JIA',
#      'direction': 118,
#      'type': 'CRJ7',
#      'ident': 'JIA5143',
#      'icon': 'jet_swept',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236620'},
#      'origin': {'icao': 'KROC', 'iata': 'ROC', 'isUSAirport': True},
#      'destination': {'icao': 'KPHL',
#       'iata': 'PHL',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 5100,
#      'projected': 0,
#      'altitude': 150,
#      'altitudeChange': 'D',
#      'groundspeed': 399}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-78.18829, 43.10229]},
#     'properties': {'flight_id': 'N353AH-1604234286-adhoc-0:0',
#      'prefix': 'N35',
#      'direction': 319,
#      'type': 'H500',
#      'ident': 'N353AH',
#      'icon': 'helicopter',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '43.14N/77.97W', 'iata': None, 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 11,
#      'projected': 0,
#      'altitude': 11,
#      'altitudeChange': 'D',
#      'groundspeed': 32}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-87.49462, 41.03696]},
#     'properties': {'flight_id': 'SWA1988-1604061857-airline-0171:0',
#      'prefix': 'SWA',
#      'direction': 160,
#      'type': 'B737',
#      'ident': 'SWA1988',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604242140'},
#      'origin': {'icao': 'KMDW', 'iata': 'MDW', 'isUSAirport': True},
#      'destination': {'icao': 'KMCO',
#       'iata': 'MCO',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 19950,
#      'projected': 0,
#      'altitude': 266,
#      'altitudeChange': 'C',
#      'groundspeed': 440}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-93.24812, 42.48804]},
#     'properties': {'flight_id': 'N5287Y-1604235040-adhoc-0:0',
#      'prefix': 'N52',
#      'direction': 81,
#      'type': 'T210',
#      'ident': 'N5287Y',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KIFA', 'iata': 'IFA', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 12,
#      'projected': 0,
#      'altitude': 12,
#      'altitudeChange': 'C',
#      'groundspeed': 153}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-165.86667, 42.1]},
#     'properties': {'flight_id': 'UAL858-1603965829-fa-0010:0',
#      'prefix': 'UAL',
#      'direction': 89,
#      'type': 'B77W',
#      'ident': 'UAL858',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604249760'},
#      'origin': {'icao': 'ZSPD', 'iata': 'PVG', 'isUSAirport': False},
#      'destination': {'icao': 'KSFO',
#       'iata': 'SFO',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 123420,
#      'projected': 0,
#      'altitude': 330,
#      'altitudeChange': '-',
#      'groundspeed': 586}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-78.66193, 40.71126]},
#     'properties': {'flight_id': 'FDX5026-1604162690-13-0-174:0',
#      'prefix': 'FDX',
#      'direction': 68,
#      'type': 'MD11',
#      'ident': 'FDX5026',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604257966'},
#      'origin': {'icao': 'KMEM', 'iata': 'MEM', 'isUSAirport': True},
#      'destination': {'icao': 'LFPG',
#       'iata': 'CDG',
#       'TZ': ':Europe/Paris',
#       'isUSAirport': False},
#      'prominence': 89100,
#      'projected': 0,
#      'altitude': 330,
#      'altitudeChange': 'C',
#      'groundspeed': 588}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-79.57597, 40.53331]},
#     'properties': {'flight_id': 'N474LF-1604234357-adhoc-0:0',
#      'prefix': 'N47',
#      'direction': 257,
#      'type': 'EC45',
#      'ident': 'N474LF',
#      'icon': 'helicopter',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '40.61N/79.16W', 'iata': None, 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 25,
#      'projected': 0,
#      'altitude': 25,
#      'altitudeChange': 'D',
#      'groundspeed': 94}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.70087, 26.20844]},
#     'properties': {'flight_id': 'N202EX-1604163520-11-8-123:0',
#      'prefix': 'N20',
#      'direction': 52,
#      'type': 'F2TH',
#      'ident': 'N202EX',
#      'icon': 'jet_swept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604256756'},
#      'origin': {'icao': 'KAPF', 'iata': 'APF', 'isUSAirport': True},
#      'destination': {'icao': 'KBFI',
#       'iata': 'BFI',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 6293,
#      'projected': 0,
#      'altitude': 29,
#      'altitudeChange': 'C',
#      'groundspeed': 232}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-90.85499, 29.64921]},
#     'properties': {'flight_id': 'N314SS-1604234744-adhoc-0:0',
#      'prefix': 'N31',
#      'direction': 297,
#      'type': 'A189',
#      'ident': 'ERH314',
#      'icon': 'helicopter',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KHUM', 'iata': 'HUM', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 12,
#      'projected': 0,
#      'altitude': 12,
#      'altitudeChange': '-',
#      'groundspeed': 136}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-77.19303, 36.35143]},
#     'properties': {'flight_id': 'EJA620-1604147746-3-6-16:0',
#      'prefix': 'EJA',
#      'direction': 196,
#      'type': 'C68A',
#      'ident': 'EJA620',
#      'icon': 'jet_nonswept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604241480'},
#      'origin': {'icao': 'KBWI', 'iata': 'BWI', 'isUSAirport': True},
#      'destination': {'icao': 'KRSW',
#       'iata': 'RSW',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 32800,
#      'projected': 0,
#      'altitude': 400,
#      'altitudeChange': '-',
#      'groundspeed': 410}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-90.46181, 41.96172]},
#     'properties': {'flight_id': 'EJA619-1604207463-0-1-16:0',
#      'prefix': 'EJA',
#      'direction': 281,
#      'type': 'C56X',
#      'ident': 'EJA619',
#      'icon': 'jet_nonswept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604238647'},
#      'origin': {'icao': 'KMDW', 'iata': 'MDW', 'isUSAirport': True},
#      'destination': {'icao': 'KSUX',
#       'iata': 'SUX',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 20000,
#      'projected': 0,
#      'altitude': 400,
#      'altitudeChange': 'C',
#      'groundspeed': 327}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.48853, 41.37149]},
#     'properties': {'flight_id': 'DAL2014-1604031128-fa-0005:0',
#      'prefix': 'DAL',
#      'direction': 291,
#      'type': 'B739',
#      'ident': 'DAL2014',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604240700'},
#      'origin': {'icao': 'KPHL', 'iata': 'PHL', 'isUSAirport': True},
#      'destination': {'icao': 'KMSP',
#       'iata': 'MSP',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 32680,
#      'projected': 0,
#      'altitude': 380,
#      'altitudeChange': '-',
#      'groundspeed': 377}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-92.1679, 29.89792]},
#     'properties': {'flight_id': 'RLC763-1604232314-adhoc-0:0',
#      'prefix': 'RLC',
#      'direction': 172,
#      'type': 'S76',
#      'ident': 'RLC763',
#      'icon': 'helicopter',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '29.90N/92.17W', 'iata': None, 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': -2,
#      'projected': 0,
#      'altitude': -2,
#      'altitudeChange': 'D',
#      'groundspeed': 58}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-76.86216, 37.41339]},
#     'properties': {'flight_id': 'N916SY-1604223265-1-2-230:0',
#      'prefix': 'N91',
#      'direction': 205,
#      'type': 'SR22',
#      'ident': 'N916SY',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '1604241300'},
#      'origin': {'icao': 'KLOM', 'iata': 'LOM', 'isUSAirport': True},
#      'destination': {'icao': '60J',
#       'iata': '60J',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 8502,
#      'projected': 0,
#      'altitude': 78,
#      'altitudeChange': '-',
#      'groundspeed': 149}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-171.94009, 12.60062]},
#     'properties': {'flight_id': 'UAL863-1603995742-fa-0000:1',
#      'prefix': 'UAL',
#      'direction': 218,
#      'type': 'B789',
#      'ident': 'UAL863',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604263029'},
#      'origin': {'icao': 'KSFO', 'iata': 'SFO', 'isUSAirport': True},
#      'destination': {'icao': 'YSSY',
#       'iata': 'SYD',
#       'TZ': ':Australia/Sydney',
#       'isUSAirport': False},
#      'prominence': 195700,
#      'projected': 1}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-77.35315, 40.49272]},
#     'properties': {'flight_id': 'RPA4374-1604061120-schedule-0074:0',
#      'prefix': 'RPA',
#      'direction': 131,
#      'type': 'E170',
#      'ident': 'RPA4374',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236320'},
#      'origin': {'icao': 'KBUF', 'iata': 'BUF', 'isUSAirport': True},
#      'destination': {'icao': 'KPHL',
#       'iata': 'PHL',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 5771,
#      'projected': 0,
#      'altitude': 199,
#      'altitudeChange': 'D',
#      'groundspeed': 402}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.98468, 38.52421]},
#     'properties': {'flight_id': 'DAL2021-1604030956-fa-0003:0',
#      'prefix': 'DAL',
#      'direction': 316,
#      'type': 'A320',
#      'ident': 'DAL2021',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604240940'},
#      'origin': {'icao': 'KRDU', 'iata': 'RDU', 'isUSAirport': True},
#      'destination': {'icao': 'KMSP',
#       'iata': 'MSP',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 29160,
#      'projected': 0,
#      'altitude': 360,
#      'altitudeChange': 'D',
#      'groundspeed': 398}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-88.11047, 37.35733]},
#     'properties': {'flight_id': 'FDX5035-1604147805-5-1-107:0',
#      'prefix': 'FDX',
#      'direction': 206,
#      'type': 'MD11',
#      'ident': 'FDX5035',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604237580'},
#      'origin': {'icao': 'KIND', 'iata': 'IND', 'isUSAirport': True},
#      'destination': {'icao': 'KMEM',
#       'iata': 'MEM',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 12480,
#      'projected': 0,
#      'altitude': 320,
#      'altitudeChange': 'C',
#      'groundspeed': 454}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-137.93753, 40.67262]},
#     'properties': {'flight_id': 'AIC173-1604010600-schedule-0370:2',
#      'prefix': 'AIC',
#      'direction': 103,
#      'type': 'B77L',
#      'ident': 'AIC173',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604241103'},
#      'origin': {'icao': 'VIDP', 'iata': 'DEL', 'isUSAirport': False},
#      'destination': {'icao': 'KSFO',
#       'iata': 'SFO',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 204980,
#      'projected': 1}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-146.35127, 24.72568]},
#     'properties': {'flight_id': 'UAL870-1604027580-schedule-0604:1',
#      'prefix': 'UAL',
#      'direction': 49,
#      'type': 'B789',
#      'ident': 'UAL870',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604246220'},
#      'origin': {'icao': 'YSSY', 'iata': 'SYD', 'isUSAirport': False},
#      'destination': {'icao': 'KSFO',
#       'iata': 'SFO',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 175180,
#      'projected': 1}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-94.50082, 45.94143]},
#     'properties': {'flight_id': 'SKW3504-1604059200-schedule-0076:0',
#      'prefix': 'SKW',
#      'direction': 119,
#      'type': 'CRJ9',
#      'ident': 'SKW3504',
#      'icon': 'jet_swept',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236080'},
#      'origin': {'icao': 'KBIS', 'iata': 'BIS', 'isUSAirport': True},
#      'destination': {'icao': 'KMSP',
#       'iata': 'MSP',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 6720,
#      'projected': 0,
#      'altitude': 224,
#      'altitudeChange': 'D',
#      'groundspeed': 467}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-82.47239, 31.23548]},
#     'properties': {'flight_id': 'UAL2338-1604050677-fa-0002:0',
#      'prefix': 'UAL',
#      'direction': 27,
#      'type': 'A319',
#      'ident': 'UAL2338',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604239920'},
#      'origin': {'icao': 'KTPA', 'iata': 'TPA', 'isUSAirport': True},
#      'destination': {'icao': 'KIAD',
#       'iata': 'IAD',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 24050,
#      'projected': 0,
#      'altitude': 370,
#      'altitudeChange': '-',
#      'groundspeed': 470}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.68719, 29.94637]},
#     'properties': {'flight_id': 'N7459T-1604233963-adhoc-0',
#      'prefix': 'N74',
#      'direction': 344,
#      'type': 'C172',
#      'ident': 'N7459T',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '16FD', 'iata': '16FD', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 23,
#      'projected': 0,
#      'altitude': 23,
#      'altitudeChange': 'C',
#      'groundspeed': 103}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-94.73618, 28.24478]},
#     'properties': {'flight_id': 'ERH328-1604233056-adhoc-0:0',
#      'prefix': 'ERH',
#      'direction': 173,
#      'type': 'A139',
#      'ident': 'ERH328',
#      'icon': 'helicopter',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KGLS', 'iata': 'GLS', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 14,
#      'projected': 0,
#      'altitude': 14,
#      'altitudeChange': '-',
#      'groundspeed': 154}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-164.19382, 41.10323]},
#     'properties': {'flight_id': 'ANA6-1604045280-schedule-0735:0',
#      'prefix': 'ANA',
#      'direction': 90,
#      'type': 'B77W',
#      'ident': 'ANA6',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604252119'},
#      'origin': {'icao': 'RJAA', 'iata': 'NRT', 'isUSAirport': False},
#      'destination': {'icao': 'KLAX',
#       'iata': 'LAX',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 117250,
#      'projected': 1}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.85483, 41.4473]},
#     'properties': {'flight_id': 'SWA2118-1604057181-airline-0242:0',
#      'prefix': 'SWA',
#      'direction': 274,
#      'type': 'B737',
#      'ident': 'SWA2118',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604237220'},
#      'origin': {'icao': 'KLGA', 'iata': 'LGA', 'isUSAirport': True},
#      'destination': {'icao': 'KMDW',
#       'iata': 'MDW',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 25460,
#      'projected': 0,
#      'altitude': 380,
#      'altitudeChange': '-',
#      'groundspeed': 393}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-91.75889, 37.89254]},
#     'properties': {'flight_id': 'N107JG-1604228468-1-2-245:0',
#      'prefix': 'N10',
#      'direction': 72,
#      'type': 'C525',
#      'ident': 'N107JG',
#      'icon': 'jet_nonswept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604242200'},
#      'origin': {'icao': 'KLBO', 'iata': 'LBO', 'isUSAirport': True},
#      'destination': {'icao': 'KTTN',
#       'iata': 'TTN',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 17100,
#      'projected': 0,
#      'altitude': 225,
#      'altitudeChange': 'C',
#      'groundspeed': 357}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-84.38588, 27.67744]},
#     'properties': {'flight_id': 'UAL2344-1604051811-fa-0005:0',
#      'prefix': 'UAL',
#      'direction': 285,
# ...
#      'icon': 'jet_swept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604236779'},
#      'origin': {'icao': 'KLRD', 'iata': 'LRD', 'isUSAirport': True},
#      'destination': {'icao': 'MNMG',
#       'iata': 'MGA',
#       'TZ': ':America/Managua',
#       'isUSAirport': False},
#      'prominence': 36050,
#      'projected': 0,
#      'altitude': 350,
#      'altitudeChange': 'D',
#      'groundspeed': 443}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.21953, 23.82637]},
#     'properties': {'flight_id': 'TPA4034-1604223724-adhoc-0:0',
#      'prefix': 'TPA',
#      'direction': 356,
#      'type': 'A332',
#      'ident': 'TPA4034',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236275'},
#      'origin': {'icao': 'SEQM', 'iata': 'UIO', 'isUSAirport': False},
#      'destination': {'icao': 'KMIA',
#       'iata': 'MIA',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 40125,
#      'projected': 0,
#      'altitude': 321,
#      'altitudeChange': 'D',
#      'groundspeed': 473}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-82.57625, 28.18689]},
#     'properties': {'flight_id': 'GTI3804-1604217946-17-2-46:0',
#      'prefix': 'GTI',
#      'direction': 332,
#      'type': 'B763',
#      'ident': 'GTI3804',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604241480'},
#      'origin': {'icao': 'KTPA', 'iata': 'TPA', 'isUSAirport': True},
#      'destination': {'icao': 'KCVG',
#       'iata': 'CVG',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 6240,
#      'projected': 0,
#      'altitude': 96,
#      'altitudeChange': 'C',
#      'groundspeed': 291}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-76.65851, 36.81635]},
#     'properties': {'flight_id': 'FFT803-1604060220-schedule-0063:0',
#      'prefix': 'FFT',
#      'direction': 207,
#      'type': 'A20N',
#      'ident': 'FFT803',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604240700'},
#      'origin': {'icao': 'KTTN', 'iata': 'TTN', 'isUSAirport': True},
#      'destination': {'icao': 'KMCO',
#       'iata': 'MCO',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 29640,
#      'projected': 0,
#      'altitude': 380,
#      'altitudeChange': '-',
#      'groundspeed': 410}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-93.4278, 40.68563]},
#     'properties': {'flight_id': 'AAL2847-1604039165-airline-0423:0',
#      'prefix': 'AAL',
#      'direction': 249,
#      'type': 'A321',
#      'ident': 'AAL2847',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604244000'},
#      'origin': {'icao': 'KORD', 'iata': 'ORD', 'isUSAirport': True},
#      'destination': {'icao': 'KPHX',
#       'iata': 'PHX',
#       'TZ': ':America/Phoenix',
#       'isUSAirport': True},
#      'prominence': 38760,
#      'projected': 0,
#      'altitude': 340,
#      'altitudeChange': '-',
#      'groundspeed': 404}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-84.93418, 32.57777]},
#     'properties': {'flight_id': 'DAL1541-1604031156-fa-0000:0',
#      'prefix': 'DAL',
#      'direction': 348,
#      'type': 'B752',
#      'ident': 'DAL1541',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604237100'},
#      'origin': {'icao': 'KTPA', 'iata': 'TPA', 'isUSAirport': True},
#      'destination': {'icao': 'KATL',
#       'iata': 'ATL',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 9200,
#      'projected': 0,
#      'altitude': 200,
#      'altitudeChange': 'D',
#      'groundspeed': 430}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-87.17383, 36.65207]},
#     'properties': {'flight_id': 'N485V-1604234050-adhoc-0:0',
#      'prefix': 'N48',
#      'direction': 50,
#      'type': 'C172',
#      'ident': 'N485V',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KCKV', 'iata': 'CKV', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 30,
#      'projected': 0,
#      'altitude': 30,
#      'altitudeChange': '-',
#      'groundspeed': 41}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.71667, 26.6553]},
#     'properties': {'flight_id': 'N43171-1604234531-adhoc-0:0',
#      'prefix': 'N43',
#      'direction': 141,
#      'type': 'P28A',
#      'ident': 'N43171',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KFMY', 'iata': 'FMY', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 1,
#      'projected': 0,
#      'altitude': 0,
#      'altitudeChange': '-',
#      'groundspeed': 70}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-82.34291, 31.61116]},
#     'properties': {'flight_id': 'DAL1544-1604031153-fa-0000:0',
#      'prefix': 'DAL',
#      'direction': 333,
#      'type': 'B752',
#      'ident': 'DAL1544',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604237880'},
#      'origin': {'icao': 'KMCO', 'iata': 'MCO', 'isUSAirport': True},
#      'destination': {'icao': 'KATL',
#       'iata': 'ATL',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 16100,
#      'projected': 0,
#      'altitude': 350,
#      'altitudeChange': '-',
#      'groundspeed': 419}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-93.50255, 30.33805]},
#     'properties': {'flight_id': 'LXJ550-1604177311-1-0-48:0',
#      'prefix': 'LXJ',
#      'direction': 300,
#      'type': 'CL30',
#      'ident': 'LXJ550',
#      'icon': 'jet_swept',
#      'ga': True,
#      'landingTimes': {'estimated': '1604241600'},
#      'origin': {'icao': 'KFLL', 'iata': 'FLL', 'isUSAirport': True},
#      'destination': {'icao': 'KLVS',
#       'iata': 'LVS',
#       'TZ': ':America/Denver',
#       'isUSAirport': True},
#      'prominence': 57190,
#      'projected': 0,
#      'altitude': 430,
#      'altitudeChange': 'D',
#      'groundspeed': 404}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-128.47961, 44.52063]},
#     'properties': {'flight_id': 'ASA246-1604047253-airline-0026:0',
#      'prefix': 'ASA',
#      'direction': 51,
#      'type': 'B739',
#      'ident': 'ASA246',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604238240'},
#      'origin': {'icao': 'PHNL', 'iata': 'HNL', 'isUSAirport': True},
#      'destination': {'icao': 'KSEA',
#       'iata': 'SEA',
#       'TZ': ':America/Los_Angeles',
#       'isUSAirport': True},
#      'prominence': 66230,
#      'projected': 0,
#      'altitude': 370,
#      'altitudeChange': '-',
#      'groundspeed': 464}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-85.30766, 34.76216]},
#     'properties': {'flight_id': 'UAL492-1604051810-fa-0007:0',
#      'prefix': 'UAL',
#      'direction': 236,
#      'type': 'B739',
#      'ident': 'UAL492',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604241120'},
#      'origin': {'icao': 'KEWR', 'iata': 'EWR', 'isUSAirport': True},
#      'destination': {'icao': 'KIAH',
#       'iata': 'IAH',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 45000,
#      'projected': 0,
#      'altitude': 360,
#      'altitudeChange': '-',
#      'groundspeed': 357}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-83.65409, 42.94081]},
#     'properties': {'flight_id': 'AAL1487-1604056560-schedule-0000:0',
#      'prefix': 'AAL',
#      'direction': 277,
#      'type': 'A321',
#      'ident': 'AAL1487',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604248620'},
#      'origin': {'icao': 'KJFK', 'iata': 'JFK', 'isUSAirport': True},
#      'destination': {'icao': 'KPHX',
#       'iata': 'PHX',
#       'TZ': ':America/Phoenix',
#       'isUSAirport': True},
#      'prominence': 62062,
#      'projected': 0,
#      'altitude': 341,
#      'altitudeChange': '-',
#      'groundspeed': 416}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.18353, 41.96718]},
#     'properties': {'flight_id': 'SWA1640-1604060917-airline-0006:0',
#      'prefix': 'SWA',
#      'direction': 258,
#      'type': 'B738',
#      'ident': 'SWA1640',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604238300'},
#      'origin': {'icao': 'KBUF', 'iata': 'BUF', 'isUSAirport': True},
#      'destination': {'icao': 'KMDW',
#       'iata': 'MDW',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 18400,
#      'projected': 0,
#      'altitude': 400,
#      'altitudeChange': '-',
#      'groundspeed': 389}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-78.48221, 30.65362]},
#     'properties': {'flight_id': 'NKS2466-1604059380-schedule-0076:0',
#      'prefix': 'NKS',
#      'direction': 8,
#      'type': 'A20N',
#      'ident': 'NKS2466',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604239980'},
#      'origin': {'icao': 'KFLL', 'iata': 'FLL', 'isUSAirport': True},
#      'destination': {'icao': 'KBWI',
#       'iata': 'BWI',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 27750,
#      'projected': 0,
#      'altitude': 370,
#      'altitudeChange': 'D',
#      'groundspeed': 437}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-95.53315, 30.14788]},
#     'properties': {'flight_id': 'N724RJ-1604234131-adhoc-0:0',
#      'prefix': 'N72',
#      'direction': 19,
#      'type': 'C182',
#      'ident': 'N724RJ',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'KIWS', 'iata': 'IWS', 'isUSAirport': True},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 52,
#      'projected': 0,
#      'altitude': 52,
#      'altitudeChange': '-',
#      'groundspeed': 100}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-81.7247, 26.72278]},
#     'properties': {'flight_id': 'UAL1866-1604051815-fa-0001:0',
#      'prefix': 'UAL',
#      'direction': 357,
#      'type': 'B737',
#      'ident': 'UAL1866',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604244480'},
#      'origin': {'icao': 'KRSW', 'iata': 'RSW', 'isUSAirport': True},
#      'destination': {'icao': 'KORD',
#       'iata': 'ORD',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 8075,
#      'projected': 0,
#      'altitude': 85,
#      'altitudeChange': 'C',
#      'groundspeed': 290}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-104.30145, 35.26206]},
#     'properties': {'flight_id': 'CKS403-1604212516-2-2-25:0',
#      'prefix': 'CKS',
#      'direction': 76,
#      'type': 'B763',
#      'ident': 'CKS403',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604244540'},
#      'origin': {'icao': 'KLAX', 'iata': 'LAX', 'isUSAirport': True},
#      'destination': {'icao': 'KCVG',
#       'iata': 'CVG',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 42930,
#      'projected': 0,
#      'altitude': 270,
#      'altitudeChange': '-',
#      'groundspeed': 441}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-95.74568, 31.95504]},
#     'properties': {'flight_id': 'SCX3025-1604217966-15-0-221:0',
#      'prefix': 'SCX',
#      'direction': 295,
#      'type': 'B738',
#      'ident': 'SCX3025',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236440'},
#      'origin': {'icao': 'KLAL', 'iata': 'LAL', 'isUSAirport': True},
#      'destination': {'icao': 'KAFW',
#       'iata': 'AFW',
#       'TZ': ':America/Chicago',
#       'isUSAirport': True},
#      'prominence': 25245,
#      'projected': 0,
#      'altitude': 297,
#      'altitudeChange': 'D',
#      'groundspeed': 376}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-139.28596, 71.50517]},
#     'properties': {'flight_id': 'B2043-1604209444-adhoc-0:0',
#      'prefix': 'B20',
#      'direction': 97,
#      'type': '',
#      'ident': 'B-2043',
#      'icon': 'unknown',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': 'ZBAA', 'iata': 'PEK', 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 330,
#      'projected': 0,
#      'altitude': 330,
#      'altitudeChange': '-',
#      'groundspeed': 496}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-76.7008, 20.00459]},
#     'properties': {'flight_id': 'TPA4055-1604226430-1-1-137:0',
#      'prefix': 'TPA',
#      'direction': 108,
#      'type': 'A332',
#      'ident': 'TPA4055',
#      'icon': 'heavy_2e',
#      'ga': False,
#      'landingTimes': {'estimated': '1604259038'},
#      'origin': {'icao': 'KMIA', 'iata': 'MIA', 'isUSAirport': True},
#      'destination': {'icao': 'SBCT',
#       'iata': 'CWB',
#       'TZ': ':America/Sao_Paulo',
#       'isUSAirport': False},
#      'prominence': 95200,
#      'projected': 0,
#      'altitude': 350,
#      'altitudeChange': 'D',
#      'groundspeed': 458}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-96.10266, 41.2558]},
#     'properties': {'flight_id': 'SKW3138-1604061960-schedule-0000:0',
#      'prefix': 'SKW',
#      'direction': 235,
#      'type': 'CRJ7',
#      'ident': 'SKW3138',
#      'icon': 'jet_swept',
#      'ga': False,
#      'landingTimes': {'estimated': '1604243160'},
#      'origin': {'icao': 'KOMA', 'iata': 'OMA', 'isUSAirport': True},
#      'destination': {'icao': 'KPHX',
#       'iata': 'PHX',
#       'TZ': ':America/Phoenix',
#       'isUSAirport': True},
#      'prominence': 6888,
#      'projected': 0,
#      'altitude': 84,
#      'altitudeChange': 'C',
#      'groundspeed': 277}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-99.06166, 19.44379]},
#     'properties': {'flight_id': 'AAL1498-1604062168-airline-0370:0',
#      'prefix': 'AAL',
#      'direction': 60,
#      'type': 'A319',
#      'ident': 'AAL1498',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604246667'},
#      'origin': {'icao': 'MMMX', 'iata': 'MEX', 'isUSAirport': False},
#      'destination': {'icao': 'KMIA',
#       'iata': 'MIA',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 8970,
#      'projected': 0,
#      'altitude': 78,
#      'altitudeChange': 'C',
#      'groundspeed': 175}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-80.42487, 39.93791]},
#     'properties': {'flight_id': 'N87RM-1604232960-adhoc-0:0',
#      'prefix': 'N87',
#      'direction': 113,
#      'type': 'C208',
#      'ident': 'N87RM',
#      'icon': 'cessna',
#      'ga': True,
#      'landingTimes': {'estimated': '0'},
#      'origin': {'icao': '40.87N/82.23W', 'iata': None, 'isUSAirport': False},
#      'destination': {'icao': '---',
#       'iata': None,
#       'TZ': '',
#       'isUSAirport': False},
#      'prominence': 34,
#      'projected': 0,
#      'altitude': 34,
#      'altitudeChange': 'C',
#      'groundspeed': 185}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point', 'coordinates': [-85.72546, 34.94974]},
#     'properties': {'flight_id': 'DAL1560-1604030885-fa-0003:0',
#      'prefix': 'DAL',
#      'direction': 142,
#      'type': 'A321',
#      'ident': 'DAL1560',
#      'icon': 'airliner',
#      'ga': False,
#      'landingTimes': {'estimated': '1604236440'},
#      'origin': {'icao': 'KIND', 'iata': 'IND', 'isUSAirport': True},
#      'destination': {'icao': 'KATL',
#       'iata': 'ATL',
#       'TZ': ':America/New_York',
#       'isUSAirport': True},
#      'prominence': 10998,
#      'projected': 0,
#      'altitude': 282,
#      'altitudeChange': 'D',
#      'groundspeed': 488}}]}]
